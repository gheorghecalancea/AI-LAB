# %% [markdown]
# # Arborele de decizie

# %% [markdown]
# ### Importăm librăriile necesare

# %%
# Încărcarea librăriilor
import pandas as pd # Dataframe-ul și series-ul nostru
from sklearn.tree import DecisionTreeClassifier # Importăm Clasificatorul „Arborele decizional”
from sklearn.model_selection import train_test_split # Importăm funcția de separare a datelor în date de antrenare și date de testare
from sklearn import metrics #Importăm modulel metrici pentru caluclarea acurateții

# %% [markdown]
# ### Importăm setul de date

# %%
bears = pd.read_csv("bears.csv",header = 1, delimiter=',')
bears.columns = ['age','month',
                        'sex','headlen',
                        'headwth','neck',
                        'length','chest',
                        'weight'
                       ]
bears
# Out:
#     age  month  sex  headlen  headwth  neck  length  chest  weight
# 0    81      9    1     15.5      8.0  31.0    72.0   54.0     416
# 1   115      7    1     17.0     10.0  31.5    72.0   49.0     348
# 2   104      8    2     15.5      6.5  22.0    62.0   35.0     166
# 3   100      4    2     13.0      7.0  21.0    70.0   41.0     220
# 4    56      7    1     15.0      7.5  26.5    73.5   41.0     262
# 5    51      4    1     13.5      8.0  27.0    68.5   49.0     360
# 6    57      9    2     13.5      7.0  20.0    64.0   38.0     204
# 7    53      5    2     12.5      6.0  18.0    58.0   31.0     144
# 8    68      8    1     16.0      9.0  29.0    73.0   44.0     332
# 9     8      8    1      9.0      4.5  13.0    37.0   19.0      34
# 10   44      8    2     12.5      4.5  10.5    63.0   32.0     140
# 11   32      8    1     14.0      5.0  21.5    67.0   37.0     180
# 12   20      8    2     11.5      5.0  17.5    52.0   29.0     105
# 13   32      8    1     13.0      8.0  21.5    59.0   33.0     166
# 14   45      9    1     13.5      7.0  24.0    64.0   39.0     204
# 15    9      9    2      9.0      4.5  12.0    36.0   19.0      26
# 16   21      9    1     13.0      6.0  19.0    59.0   30.0     120
# 17  177      9    1     16.0      9.5  30.0    72.0   48.0     436
# 18   57      9    2     12.5      5.0  19.0    57.5   32.0     125
# 19   81      9    2     13.0      5.0  20.0    61.0   33.0     132
# 20   21      9    1     13.0      5.0  17.0    54.0   28.0      90
# 21    9      9    1     10.0      4.0  13.0    40.0   23.0      40
# 22   45      9    1     16.0      6.0  24.0    63.0   42.0     220
# 23    9      9    1     10.0      4.0  13.5    43.0   23.0      46
# 24   33      9    1     13.5      6.0  22.0    66.5   34.0     154
# 25   57      9    2     13.0      5.5  17.5    60.5   31.0     116
# 26   45      9    2     13.0      6.5  21.0    60.0   34.5     182
# 27   21      9    1     14.5      5.5  20.0    61.0   34.0     150
# 28   10     10    1      9.5      4.5  16.0    40.0   26.0      65
# 29   82     10    2     13.5      6.5  28.0    64.0   48.0     356
# 30   70     10    2     14.5      6.5  26.0    65.0   48.0     316
# 31   10     10    1     11.0      5.0  17.0    49.0   29.0      94
# 32   10     10    1     11.5      5.0  17.0    47.0   29.5      86
# 33   34     10    1     13.0      7.0  21.0    59.0   35.0     150
# 34   34     10    1     16.5      6.5  27.0    72.0   44.5     270
# 35   34     10    1     14.0      5.5  24.0    65.0   39.0     202
# 36   58     10    2     13.5      6.5  21.5    63.0   40.0     202
# 37   58     10    1     15.5      7.0  28.0    70.5   50.0     365
# 38   11     11    1     11.5      6.0  16.5    48.0   31.0      79
# 39   23     11    1     12.0      6.5  19.0    50.0   38.0     148
# 40   70     10    1     15.5      7.0  28.0    76.5   55.0     446
# 41   11     11    2      9.0      5.0  15.0    46.0   27.0      62
# 42   83     11    2     14.5      7.0  23.0    61.5   44.0     236
# 43   35     11    1     13.5      8.5  23.0    63.5   44.0     212
# 44   16      4    1     10.0      4.0  15.5    48.0   26.0      60
# 45   16      4    1     10.0      5.0  15.0    41.0   26.0      64
# 46   17      5    1     11.5      5.0  17.0    53.0   30.5     114
# 47   17      5    2     11.5      5.0  15.0    52.5   28.0      76
# 48   17      5    2     11.0      4.5  13.0    46.0   23.0      48
# 49    8      8    2     10.0      4.5  10.0    43.5   24.0      29
# 50   83     11    1     15.5      8.0  30.5    75.0   54.0     514
# 51   18      6    1     12.5      8.5  18.0    57.3   32.8     140

# %%
from sklearn import preprocessing # preprocesarea datelor
from sklearn.preprocessing import OrdinalEncoder # functie care transforma din date categorice in numere
enc = preprocessing.OrdinalEncoder()

# caută legitate în date
enc.fit(bears)  

# transformă după legea găsită într-un array
data = enc.transform(bears)

# punem datale noatre înapoi în dataframe
bears = pd.DataFrame({'age': data[:, 0], 'month': data[:, 1], 'sex': data[:, 2], 
                       'headlen': data[:, 3], 'headwth': data[:, 4],'neck': data[:, 5],
                       'length': data[:, 6],'chest': data[:, 7],'weight': data[:, 8]})
bears


#data = enc.transform(bears)
#features = ['age','month',
                  #      'sex','headlen': data[:, 0],
                   #     'headwth': data[:, 1],'neck',
                   #     'length','chest': data[:, 2],
                   #     'weight'
                  #     ]
#X = bears[bears1] # caracteristicile (atributele pentru X)
#y = bears.headwth # Variabila clasă (independentă dacă facem analogie cu regresia)
# Out:
#      age  month  sex  headlen  headwth  neck  length  chest  weight
# 0   23.0    5.0  0.0     12.0      8.0  26.0    33.0   28.0    42.0
# 1   28.0    3.0  0.0     15.0     12.0  27.0    33.0   26.0    38.0
# 2   27.0    4.0  1.0     12.0      5.0  16.0    23.0   16.0    26.0
# 3   26.0    0.0  1.0      7.0      6.0  14.0    31.0   21.0    32.0
# 4   18.0    3.0  0.0     11.0      7.0  20.0    35.0   21.0    34.0
# 5   16.0    0.0  0.0      8.0      8.0  21.0    30.0   26.0    40.0
# 6   19.0    5.0  1.0      8.0      6.0  13.0    26.0   18.0    30.0
# 7   17.0    1.0  1.0      6.0      4.0  11.0    17.0   10.0    22.0
# 8   21.0    4.0  0.0     13.0     10.0  23.0    34.0   23.0    37.0
# 9    0.0    4.0  0.0      0.0      1.0   3.0     1.0    0.0     2.0
# 10  14.0    4.0  1.0      6.0      1.0   1.0    24.0   11.0    21.0
# 11  10.0    4.0  0.0      9.0      2.0  15.0    29.0   17.0    27.0
# 12   7.0    4.0  1.0      4.0      2.0  10.0    11.0    6.0    15.0
# 13  10.0    4.0  0.0      7.0      8.0  15.0    18.0   13.0    26.0
# 14  15.0    5.0  0.0      8.0      6.0  18.0    26.0   19.0    30.0
# 15   1.0    5.0  1.0      0.0      1.0   2.0     0.0    0.0     0.0
# 16   8.0    5.0  0.0      7.0      4.0  12.0    18.0    8.0    18.0
# 17  29.0    5.0  0.0     13.0     11.0  24.0    33.0   25.0    43.0
# 18  19.0    5.0  1.0      6.0      2.0  12.0    16.0   11.0    19.0
# 19  23.0    5.0  1.0      7.0      2.0  13.0    21.0   13.0    20.0
# 20   8.0    5.0  0.0      7.0      2.0   9.0    14.0    5.0    13.0
# 21   1.0    5.0  0.0      2.0      0.0   3.0     2.0    1.0     3.0
# 22  15.0    5.0  0.0     13.0      4.0  18.0    24.0   22.0    32.0
# 23   1.0    5.0  0.0      2.0      0.0   4.0     4.0    1.0     4.0
# 24  11.0    5.0  0.0      8.0      4.0  16.0    28.0   14.0    25.0
# 25  19.0    5.0  1.0      7.0      3.0  10.0    20.0   10.0    17.0
# 26  15.0    5.0  1.0      7.0      5.0  14.0    19.0   15.0    28.0
# 27   8.0    5.0  0.0     10.0      3.0  13.0    21.0   14.0    24.0
# 28   2.0    6.0  0.0      1.0      1.0   7.0     2.0    3.0     9.0
# 29  24.0    6.0  1.0      8.0      5.0  22.0    26.0   25.0    39.0
# 30  22.0    6.0  1.0     10.0      5.0  19.0    27.0   25.0    36.0
# 31   2.0    6.0  0.0      3.0      2.0   9.0     9.0    6.0    14.0
# 32   2.0    6.0  0.0      4.0      2.0   9.0     7.0    7.0    12.0
# 33  12.0    6.0  0.0      7.0      6.0  14.0    18.0   16.0    24.0
# 34  12.0    6.0  0.0     14.0      5.0  21.0    33.0   24.0    35.0
# 35  12.0    6.0  0.0      9.0      3.0  18.0    27.0   19.0    29.0
# 36  20.0    6.0  1.0      8.0      5.0  15.0    24.0   20.0    29.0
# 37  20.0    6.0  0.0     12.0      6.0  22.0    32.0   27.0    41.0
# 38   3.0    7.0  0.0      4.0      4.0   8.0     8.0   10.0    11.0
# 39   9.0    7.0  0.0      5.0      5.0  12.0    10.0   18.0    23.0
# 40  22.0    6.0  0.0     12.0      6.0  22.0    37.0   29.0    44.0
# 41   3.0    7.0  1.0      0.0      2.0   5.0     6.0    4.0     7.0
# 42  25.0    7.0  1.0     10.0      6.0  17.0    22.0   23.0    33.0
# 43  13.0    7.0  0.0      8.0      9.0  17.0    25.0   23.0    31.0
# 44   4.0    0.0  0.0      2.0      0.0   6.0     8.0    3.0     6.0
# 45   4.0    0.0  0.0      2.0      2.0   5.0     3.0    3.0     8.0
# 46   5.0    1.0  0.0      4.0      2.0   9.0    13.0    9.0    16.0
# 47   5.0    1.0  1.0      4.0      2.0   5.0    12.0    5.0    10.0
# 48   5.0    1.0  1.0      3.0      1.0   3.0     6.0    1.0     5.0
# 49   0.0    4.0  1.0      2.0      1.0   0.0     5.0    2.0     1.0
# 50  25.0    7.0  0.0     12.0      8.0  25.0    36.0   28.0    45.0
# 51   6.0    2.0  0.0      6.0      9.0  11.0    15.0   12.0    21.0

# %% [markdown]
# ### Împărțirea setului de date
# Pentru a evalua performanța modelului o strategie ar fie împărțirea setului de date în: date de antrenare/învățare și date pentru testare/evaluare.
#
# Putem face acest lucru utilizând funcția train_test_split(). Funcția ia 3 parametri: caracteristicile, clasa și lungimea setului de date pentru testare.

# %%
#despărțim datasetul în vector de caracteristici (features) și vectorul clasă
features = ['age', 'month', 'sex', 
                       'headlen', 'headwth','neck',
                       'length','chest','weight']
X = bears[features] # caracteristicile (atributele pentru X)
y = bears.weight # Variabila clasă (independentă dacă facem analogie cu regresia)

# %%
# Împărțim setul de date în train set și test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% pentru antrenare and 30% testare
X_test
# Out:
#      age  month  sex  headlen  headwth  neck  length  chest  weight
# 31   2.0    6.0  0.0      3.0      2.0   9.0     9.0    6.0    14.0
# 2   27.0    4.0  1.0     12.0      5.0  16.0    23.0   16.0    26.0
# 42  25.0    7.0  1.0     10.0      6.0  17.0    22.0   23.0    33.0
# 32   2.0    6.0  0.0      4.0      2.0   9.0     7.0    7.0    12.0
# 30  22.0    6.0  1.0     10.0      5.0  19.0    27.0   25.0    36.0
# 45   4.0    0.0  0.0      2.0      2.0   5.0     3.0    3.0     8.0
# 33  12.0    6.0  0.0      7.0      6.0  14.0    18.0   16.0    24.0
# 38   3.0    7.0  0.0      4.0      4.0   8.0     8.0   10.0    11.0
# 44   4.0    0.0  0.0      2.0      0.0   6.0     8.0    3.0     6.0
# 19  23.0    5.0  1.0      7.0      2.0  13.0    21.0   13.0    20.0
# 10  14.0    4.0  1.0      6.0      1.0   1.0    24.0   11.0    21.0
# 3   26.0    0.0  1.0      7.0      6.0  14.0    31.0   21.0    32.0
# 21   1.0    5.0  0.0      2.0      0.0   3.0     2.0    1.0     3.0
# 48   5.0    1.0  1.0      3.0      1.0   3.0     6.0    1.0     5.0
# 24  11.0    5.0  0.0      8.0      4.0  16.0    28.0   14.0    25.0
# 40  22.0    6.0  0.0     12.0      6.0  22.0    37.0   29.0    44.0

# %% [markdown]
# ### Construirea modelului

# %%
clasificator = DecisionTreeClassifier(criterion="entropy")
clasificator_arbore_decizie = clasificator.fit(X_train,y_train)

# %% [markdown]
# ### Evaluarea modelului

# %%
y_prezis = clasificator_arbore_decizie.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_prezis))
print(y_test, y_prezis)
# Out:
# Accuracy: 0.0
# 31    14.0
# 2     26.0
# 42    33.0
# 32    12.0
# 30    36.0
# 45     8.0
# 33    24.0
# 38    11.0
# 44     6.0
# 19    20.0
# 10    21.0
# 3     32.0
# 21     3.0
# 48     5.0
# 24    25.0
# 40    44.0
# Name: weight, dtype: float64 [16. 28. 31. 16. 41.  7. 26. 16.  7. 18. 17. 34.  4.  1. 24. 41.]

# %%
obiect_nou = [[45,29.38475666,90,4.713,1.046286,23.8479,6.644245,15.55625,621.273]]

raspuns=clasificator_arbore_decizie.predict(obiect_nou)

print(raspuns)
# Out:
# [26.]

# %% [markdown]
# ### Vizualizarea arborelui

# %% [markdown]
# Puteți folosi funcția export_graphviz din Scikit-learn pentru a afișa arborele în Jupyter Notebook. Pentru a face diagram de asemenea este nevoie de biblioteca pudotplus.
# Pentru instalarea clasică:
#
# - pip install graphviz
#
# - pip install pydotplus
#
# funcția export_graphviz transformă clasificatorul nostru intr-un fișier cu puncte, iar pydotplus convertește aceste puncte într-un fișier png.

# %%
obiect_nou = X_test[X_test["age"] == 1.0]
clasificator_arbore_decizie.predict(obiect_nou)
# Out:
# array([4.])

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
# Out:
# c:\users\ion isac\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
dot_data = StringIO()
export_graphviz(clasificator_arbore_decizie, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names = features,class_names=['1','40'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('bears.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-c8b8d7971612> in <module>
#       2 export_graphviz(clasificator_arbore_decizie, out_file=dot_data,
#       3                 filled=True, rounded=True,
# ----> 4                 special_characters=True, feature_names = features,class_names=['1','40'])
#       5 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#       6 graph.write_png('bears.png')
#
# c:\users\ion isac\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\tree\export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     774             rounded=rounded, special_characters=special_characters,
#     775             precision=precision)
# --> 776         exporter.export(decision_tree)
#     777
#     778         if return_string:
#
# c:\users\ion isac\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\tree\export.py in export(self, decision_tree)
#     407         else:
#     408             self.recurse(decision_tree.tree_, 0,
# --> 409                          criterion=decision_tree.criterion)
#     410
#     411         self.tail()
#
# c:\users\ion isac\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\tree\export.py in recurse(self, tree, node_id, criterion, parent, depth)
#     467             self.out_file.write(
#     468                 '%d [label=%s' % (node_id, self.node_to_str(tree, node_id,
# --> 469                                                             criterion)))
#     470
#     471             if self.filled:
#
# c:\users\ion isac\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\tree\export.py in node_to_str(self, tree, node_id, criterion)
#     337                 node_string += 'class = '
#     338             if self.class_names is not True:
# --> 339                 class_name = self.class_names[np.argmax(value)]
#     340             else:
#     341                 class_name = "y%s%s%s" % (characters[1],
#
# IndexError: list index out of range

# %%
graph.write_png('weather.png')
Image(graph.create_png())
